# %%
import networkx as nx
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import pandas as pd

from model import CampusModel
from collections import deque
from visualization import draw
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 import xml.etree.ElementTree as ET
#       4 import pandas as pd
# ----> 6 from model import CampusModel
#       7 from collections import deque
#       8 from visualization import draw
#
# ModuleNotFoundError: No module named 'model'

# %%
G1 = nx.read_graphml("data/distances-graph.graphml")
G2 = nx.read_graphml("data/width-graph.graphml")

G = G1.copy()

# %%
tree = ET.parse("data/distances-graph.graphml")
root = tree.getroot()

ns = {
    "g": "http://graphml.graphdrawing.org/xmlns",
    "y": "http://www.yworks.com/xml/graphml"
}

nodeTypes = {'#FFCC00': 'building',
             '#33CCCC': 'court',
             '#808080': 'temporary-point',
             '#FF0000': 'restaurant',
             '#333333': 'parking',
             '#993366': 'entry/exit',
             '#FF00FF': 'outpatient',
             '#008000': 'bank',
             '#FFCC99': 'bathroom',
             '#008080': 'turnstile'}

nodeAdditionalInformation = {}

for node in root.findall(".//g:node", ns):
    nodeID = node.attrib['id']
    for data in node:
        for ShapeNode in data:
            for x in ShapeNode:
                if 'Fill' in str(x):
                    nodeColor = x.attrib['color']
                    nodeAdditionalInformation[nodeID] = nodeTypes[nodeColor]

for id, data in G.nodes(data=True):
    data['type'] = nodeAdditionalInformation[id]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tree = ET.parse("data/distances-graph.graphml")
#       2 root = tree.getroot()
#       4 ns = {
#       5     "g": "http://graphml.graphdrawing.org/xmlns",
#       6     "y": "http://www.yworks.com/xml/graphml"
#       7 }
#
# File ~/anaconda3/envs/amb1/lib/python3.12/xml/etree/ElementTree.py:1204, in parse(source, parser)
#    1195 """Parse XML document into element tree.
#    1196
#    1197 *source* is a filename or file object containing XML data,
#    (...)
#    1201
#    1202 """
#    1203 tree = ElementTree()
# -> 1204 tree.parse(source, parser)
#    1205 return tree
#
# File ~/anaconda3/envs/amb1/lib/python3.12/xml/etree/ElementTree.py:558, in ElementTree.parse(self, source, parser)
#     556 close_source = False
#     557 if not hasattr(source, "read"):
# --> 558     source = open(source, "rb")
#     559     close_source = True
#     560 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/distances-graph.graphml'

# %%
for u, v, data in G.edges(data=True):
    data['distance'] = int(data['label'])
    data["width"] = int(G2.edges[u, v]['label'])
    data["queue"] = deque()
    data["in_transit"] = set()
    data["entered_this_step"] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for u, v, data in G.edges(data=True):
#       2     data['distance'] = int(data['label'])
#       3     data["width"] = int(G2.edges[u, v]['label'])
#
# NameError: name 'G' is not defined

# %%
G = G.to_undirected()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 G = G.to_undirected()
#
# NameError: name 'G' is not defined
