# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/flow.csv")

df.head()
# Out:
#    timestamp     u     v  in_transit  in_queue  entered_this_step  \
# 0      25201   n85   n84           9         2                  9
# 1      25201   n71   n70           6         3                  6
# 2      25201   n54  n259           8         4                  8
# 3      25201   n54  n258           2         0                  2
# 4      25201  n155  n140           3         0                  3
#
#    data_dist_buffer  data_width_buffer
# 0                17                  9
# 1                22                  6
# 2                 3                  8
# 3                 8                  2
# 4                17                  5

# %%
df.timestamp.nunique()
# Out:
# 22596

# %%
df['in_transit'].hist()
# Out:
# <Axes: >
